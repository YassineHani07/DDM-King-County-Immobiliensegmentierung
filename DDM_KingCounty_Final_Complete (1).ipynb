# %% [markdown]
# # Data Driven Modelling
# ## Immobiliensegmentierung in King County
#
# **Team:** Yassine Hani und Samuel Habte
#
# Ziel: Immobilien anhand von Lage, Größe, Qualität, Alter, Renovierung und Waterfront-Lage segmentieren und daraus mögliche Marketingansprachen ableiten.

# %%
from ddm_kingcounty_final import main
main()
# Out:
# Datensatz: /content/data_extracted/kingcounty/kc_house_data.csv
# Zeilen: 21613 | Fehlende Werte: 0
# Preisspanne: 75000 bis 7700000 US-Dollar
# K-Means wird evaluiert ...
# Agglomerative Clustering wird evaluiert ...
# DBSCAN wird evaluiert ...
# Finale Modelle werden trainiert ...
#
# Finaler Modellvergleich:
#         model               parameter  n_clusters  noise_share  silhouette  davies_bouldin  calinski_harabasz                                                        business_interpretation
#       K-Means                     k=3           3       0.0000      0.2167          1.3561          4292.4377                                   Gute Basis; weniger differenzierte Segmente.
# Agglomerative       k=4, linkage=ward           4       0.0000      0.1924          1.3024          3403.6925                      Am besten interpretierbar; vier klare Immobiliensegmente.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Methodische Entscheidung
# Drei Verfahren werden verglichen: K-Means, Agglomerative Clustering und DBSCAN. DBSCAN liefert gute numerische Werte, wird aber von einem sehr großen Hauptcluster dominiert. Für die Business-Analyse wird Agglomerative Clustering mit vier Segmenten gewählt, weil es klarer interpretierbar ist.

# %% [markdown]
# ## Einschränkungen
# - Datenstand 2014–2015
# - nur King County
# - keine direkten Käuferdaten
# - explorative Segmentierung, keine Kausalitätsaussage
